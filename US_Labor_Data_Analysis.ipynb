# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st
import numpy as np
import seaborn as sns
from scipy.stats import linregress
import statsmodels.api as sm

# %%
#Data
uslabor_data_path = "data/UnemploymentUS_State.csv"

# Read data
df = pd.read_csv(uslabor_data_path, index_col=False)

# View the first 5 rows
df.head()
# Out:
#    FIPS Code  State/Area  Year  Month  \
# 0          1     Alabama  1976      1
# 1          2      Alaska  1976      1
# 2          4     Arizona  1976      1
# 3          5    Arkansas  1976      1
# 4          6  California  1976      1
#
#   Total Civilian Non-Institutional Population in State/Area  \
# 0                                       2,605,000
# 1                                         232,000
# 2                                       1,621,000
# 3                                       1,536,000
# 4                                      15,621,000
#
#   Total Civilian Labor Force in State/Area  \
# 0                             1,484,555
# 1                               160,183
# 2                               964,120
# 3                               889,044
# 4                             9,774,280
#
#    Percent (%) of State/Area's Population Total Employment in State/Area  \
# 0                                    57.0                   1,386,023
# ...

# %%
print(df.columns)
# Out:
# Index(['FIPS Code', 'State/Area', 'Year', 'Month',
#        'Total Civilian Non-Institutional Population in State/Area',
#        'Total Civilian Labor Force in State/Area',
#        'Percent (%) of State/Area's Population',
#        'Total Employment in State/Area',
#        'Percent (%) of Labor Force Employed in State/Area',
#        'Total Unemployment in State/Area',
#        'Percent (%) of Labor Force Unemployed in State/Area'],
#       dtype='object')

# %%
df.shape
# Out:
# (29892, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29892 entries, 0 to 29891
# Data columns (total 11 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   FIPS Code                                                  29892 non-null  int64
#  1   State/Area                                                 29892 non-null  object
#  2   Year                                                       29892 non-null  int64
#  3   Month                                                      29892 non-null  int64
#  4   Total Civilian Non-Institutional Population in State/Area  29892 non-null  object
#  5   Total Civilian Labor Force in State/Area                   29892 non-null  object
#  6   Percent (%) of State/Area's Population                     29892 non-null  float64
# ...

# %%
df.drop(['FIPS Code'], axis='columns', inplace=True)
df.head()
# Out:
#    State/Area  Year  Month  \
# 0     Alabama  1976      1
# 1      Alaska  1976      1
# 2     Arizona  1976      1
# 3    Arkansas  1976      1
# 4  California  1976      1
#
#   Total Civilian Non-Institutional Population in State/Area  \
# 0                                       2,605,000
# 1                                         232,000
# 2                                       1,621,000
# 3                                       1,536,000
# 4                                      15,621,000
#
#   Total Civilian Labor Force in State/Area  \
# 0                             1,484,555
# 1                               160,183
# 2                               964,120
# 3                               889,044
# 4                             9,774,280
#
#    Percent (%) of State/Area's Population Total Employment in State/Area  \
# 0                                    57.0                   1,386,023
# 1                                    69.0                     148,820
# ...

# %%
df.Year.max()
# Out:
# 2022

# %%
df.Year.min()
# Out:
# 1976

# %%
short_df = df.loc[df['Year'].isin([2022, 2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013])]
short_df.head()
# Out:
#        State/Area  Year  Month  \
# 23532     Alabama  2013      1
# 23533      Alaska  2013      1
# 23534     Arizona  2013      1
# 23535    Arkansas  2013      1
# 23536  California  2013      1
#
#       Total Civilian Non-Institutional Population in State/Area  \
# 23532                                       3,757,648
# 23533                                         537,343
# 23534                                       5,050,211
# 23535                                       2,272,945
# 23536                                      29,482,749
#
#       Total Civilian Labor Force in State/Area  \
# 23532                             2,181,651
# 23533                               364,023
# 23534                             3,058,620
# 23535                             1,338,053
# 23536                            18,564,212
#
#        Percent (%) of State/Area's Population Total Employment in State/Area  \
# 23532                                    58.1                   2,015,043
# ...

# %%
short_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6360 entries, 23532 to 29891
# Data columns (total 10 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   State/Area                                                 6360 non-null   object
#  1   Year                                                       6360 non-null   int64
#  2   Month                                                      6360 non-null   int64
#  3   Total Civilian Non-Institutional Population in State/Area  6360 non-null   object
#  4   Total Civilian Labor Force in State/Area                   6360 non-null   object
#  5   Percent (%) of State/Area's Population                     6360 non-null   float64
#  6   Total Employment in State/Area                             6360 non-null   object
# ...

# %%
short_df.to_csv('USData.csv', index=False)
